# %%
#Comprobar la versión 
R.version
# Out:
#                _
# platform       x86_64-w64-mingw32
# arch           x86_64
# os             mingw32
# system         x86_64, mingw32
# status
# major          3
# minor          6.1
# year           2019
# month          07
# day            05
# svn rev        76782
# language       R
# version.string R version 3.6.1 (2019-07-05)
# nickname       Action of the Toes

# %%
install.packages("devtools")
devtools::install_github("kassambara/factoextra")
# Out:
# also installing the dependency 'ellipsis'
# package 'ellipsis' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'ellipsis'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problema al copiar C:\Users\Miguel\.conda\envs\rstudio\lib\R\library\00LOCK\ellipsis\libs\x64\ellipsis.dll.c~.conda_trash  a C:\Users\Miguel\.conda\envs\rstudio\lib\R\library\ellipsis\libs\x64\ellipsis.dll.c~.conda_trash: Permission denied"Warning message:
# "restored 'ellipsis'"
# package 'devtools' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Miguel\AppData\Local\Temp\Rtmp424URF\downloaded_packages
# Error in loadNamespace(j <- i[[1L]], c(lib.loc, .libPaths()), versionCheck = vI[[j]]): namespace 'ellipsis' 0.1.0 is being loaded, but >= 0.3.0 is required
# Traceback:
#
# 1. devtools::install_github
# 2. getExportedValue(pkg, name)
# 3. asNamespace(ns)
# 4. getNamespace(ns)
# ...

# %%
devtools::install_github("kassambara/factoextra")
# Out:
# Error in loadNamespace(j <- i[[1L]], c(lib.loc, .libPaths()), versionCheck = vI[[j]]): namespace 'ellipsis' 0.1.0 is being loaded, but >= 0.3.0 is required
# Traceback:
#
# 1. devtools::install_github
# 2. getExportedValue(pkg, name)
# 3. asNamespace(ns)
# 4. getNamespace(ns)
# 5. loadNamespace(name)
# 6. namespaceImportFrom(ns, loadNamespace(j <- i[[1L]], c(lib.loc,
#  .     .libPaths()), versionCheck = vI[[j]]), i[[2L]], from = package)
# 7. asNamespace(ns)
# 8. loadNamespace(j <- i[[1L]], c(lib.loc, .libPaths()), versionCheck = vI[[j]])
# 9. stop(gettextf("namespace %s %s is being loaded, but %s %s is required",
#  .     sQuote(package), version, zop, zversion), domain = NA)

# %%
install.packages("factoextra")
library(factoextra)
library(FactoMineR)
#library(tidyverse)
# Out:
# package 'factoextra' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Miguel\AppData\Local\Temp\Rtmp424URF\downloaded_packages
# Loading required package: ggplot2
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Welcome! Related Books: `Practical Guide To Cluster Analysis in R` at https://goo.gl/13EFCZ

# %% [markdown]
# Datos tomados desde 1964 hasta 2018

# %%
# Load the data
data <- read.table("data/Data_for_PCA_mod2.csv",header=TRUE,sep=",")
head(data)
# Out:
#   X        B_mag Proton_Temp Proton_dens Plasma_speed AP_ratio Flow_pres E
# 1 1964.001 5.90  106557.2    30.70       328.00       0.04     6.82      -1.46
# 2 1964.004 6.15  106557.2    20.78       416.72       0.04     6.06      -0.45
# 3 1964.007 5.13  106557.2    15.26       444.28       0.04     4.75      -0.23
# 4 1964.010 4.67  106557.2    12.47       456.30       0.04     4.07       0.04
# 5 1964.012 4.15  106557.2    10.88       439.88       0.04     3.51       0.12
# 6 1964.015 3.80  106557.2     9.92       428.09       0.04     3.16       0.16
#   Alfven_MN Kp    ... Proton_flux2 Proton_flux4 Proton_flux10 Proton_flux30
# 1 11.80     17.00 ... 51.17        21.27        7.53          2.19
# 2 10.45     32.04 ... 51.17        21.27        7.53          2.19
# 3 10.93     33.70 ... 51.17        21.27        7.53          2.19
# 4 11.03     33.52 ... 51.17        21.27        7.53          2.19
# 5 11.18     30.79 ... 51.17        21.27        7.53          2.19
# ...

# %%
install.packages("leaps")
install.packages("scatterplot3d")
# Out:
# package 'leaps' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'leaps'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problema al copiar C:\Users\Miguel\.conda\envs\rstudio\lib\R\library\00LOCK\leaps\libs\x64\leaps.dll  a C:\Users\Miguel\.conda\envs\rstudio\lib\R\library\leaps\libs\x64\leaps.dll: Permission denied"Warning message:
# "restored 'leaps'"
# The downloaded binary packages are in
# 	C:\Users\Miguel\AppData\Local\Temp\Rtmp424URF\downloaded_packages
# package 'scatterplot3d' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Miguel\AppData\Local\Temp\Rtmp424URF\downloaded_packages

# %%
install.packages("flashClust")
# Out:
# package 'flashClust' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'flashClust'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problema al copiar C:\Users\Miguel\.conda\envs\rstudio\lib\R\library\00LOCK\flashClust\libs\x64\flashClust.dll  a C:\Users\Miguel\.conda\envs\rstudio\lib\R\library\flashClust\libs\x64\flashClust.dll: Permission denied"Warning message:
# "restored 'flashClust'"
# The downloaded binary packages are in
# 	C:\Users\Miguel\AppData\Local\Temp\Rtmp424URF\downloaded_packages

# %% [markdown]
# ### PCA ciclo 20

# %%
install.packages("corrplot")
# Out:
# package 'corrplot' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Miguel\AppData\Local\Temp\Rtmp424URF\downloaded_packages

# %%
install.packages("ggsignif")
# Out:
# package 'ggsignif' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Miguel\AppData\Local\Temp\Rtmp424URF\downloaded_packages

# %%
data_20 <- data[273:4443,]

# %%
# Compute principal component analysis
res.pca_20 <- prcomp(data_20, scale = TRUE)
# Percentage of information retained by each dimensions
fviz_eig(res.pca_20)
# Out:
# plot without title

# %%
fviz_pca_var(res.pca_20,
             col.var = "contrib", # Color by contributions to the PC
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"),
             repel = TRUE     # Avoid text overlapping
             )
# Out:
# plot without title

# %%
# Eigenvalues
eig.val <- get_eigenvalue(res.pca_20)
eig.val
  
# Results for Variables
res.var <- get_pca_var(res.pca_20)
res.var$coord          # Coordinates
res.var$contrib        # Contributions to the PCs
res.var$cos2           # Quality of representation 
# Results for individuals
res.ind <- get_pca_ind(res.pca_20)
res.ind$coord          # Coordinates
res.ind$contrib        # Contributions to the PCs
res.ind$cos2           # Quality of representation
# Out:
#        eigenvalue   variance.percent cumulative.variance.percent
# Dim.1  9.3024912855 3.876038e+01      38.76038
# Dim.2  5.6560127509 2.356672e+01      62.32710
# Dim.3  4.0201997910 1.675083e+01      79.07793
# Dim.4  1.4282502734 5.951043e+00      85.02898
# Dim.5  0.9999501644 4.166459e+00      89.19543
# Dim.6  0.8596322346 3.581801e+00      92.77724
# Dim.7  0.5162241273 2.150934e+00      94.92817
# Dim.8  0.3186652789 1.327772e+00      96.25594
# Dim.9  0.2695280404 1.123034e+00      97.37897
# Dim.10 0.2206094553 9.192061e-01      98.29818
# Dim.11 0.1417575692 5.906565e-01      98.88884
# Dim.12 0.0986995249 4.112480e-01      99.30009
# Dim.13 0.0518461066 2.160254e-01      99.51611
# Dim.14 0.0448472766 1.868637e-01      99.70297
# Dim.15 0.0203929234 8.497051e-02      99.78795
# Dim.16 0.0135247761 5.635323e-02      99.84430
# Dim.17 0.0119152976 4.964707e-02      99.89395
# Dim.18 0.0081772626 3.407193e-02      99.92802
# Dim.19 0.0055005326 2.291889e-02      99.95094
# ...

# %%
# Compute PCA with ncp = 3
res.pca_20 <- PCA(data_20, ncp = 3, graph = FALSE)
# Compute HCPC
res.hcpc <- HCPC(res.pca_20, graph = FALSE)

# %%
# Variable describing clusters
#res.hcpc$desc.var

# %%
# Principal components + tree
plot(res.hcpc, choice = "3D.map")
# Out:
# Plot with title "Hierarchical clustering on the factor map"

# %%
# Plot the dendrogram only
#plot(res.hcpc, choice ="tree", cex = 0.6)

# %%
# Draw only the factor map
#plot(res.hcpc, choice ="map", draw.tree = FALSE)

# %%
# Remove labels and add cluster centers
#plot(res.hcpc, choice ="map", draw.tree = FALSE,
#     ind.names = FALSE, centers.plot = TRUE)

# %%
fviz_cluster(res.hcpc,choose.vars = NULL, stand = TRUE,
  axes = c(1, 2), geom = c("point", "text"), repel = FALSE,
  show.clust.cent = TRUE, ellipse = TRUE, ellipse.type = "t",
  ellipse.level = 0.95, ellipse.alpha = 0.2, shape = NULL,
  pointsize = 1.5, labelsize = 12, main = "Cluster plot", xlab = NULL,
  ylab = NULL, outlier.color = "black", outlier.shape = 19)
# Out:
# plot without title

# %% [markdown]
# ### PCA ciclo 21

# %%
data_21 <- data[4443:8340,]

# %%
# Compute principal component analysis
res.pca_21 <- prcomp(data_21, scale = TRUE)
# Percentage of information retained by each dimensions
fviz_eig(res.pca_21)
# Out:
# plot without title

# %%
fviz_pca_var(res.pca_21,
             col.var = "contrib", # Color by contributions to the PC
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"),
             repel = TRUE     # Avoid text overlapping
             )
# Out:
# plot without title

# %%
# Eigenvalues
eig.val <- get_eigenvalue(res.pca_21)
eig.val
  
# Results for Variables
res.var <- get_pca_var(res.pca_21)
res.var$coord          # Coordinates
res.var$contrib        # Contributions to the PCs
res.var$cos2           # Quality of representation 
# Results for individuals
res.ind <- get_pca_ind(res.pca_21)
res.ind$coord          # Coordinates
res.ind$contrib        # Contributions to the PCs
res.ind$cos2           # Quality of representation
# Out:
#        eigenvalue   variance.percent cumulative.variance.percent
# Dim.1  1.021223e+01 4.255097e+01      42.55097
# Dim.2  7.106827e+00 2.961178e+01      72.16275
# Dim.3  3.296223e+00 1.373426e+01      85.89702
# Dim.4  1.330434e+00 5.543473e+00      91.44049
# Dim.5  7.318074e-01 3.049198e+00      94.48969
# Dim.6  4.918142e-01 2.049226e+00      96.53891
# Dim.7  2.501371e-01 1.042238e+00      97.58115
# Dim.8  1.806565e-01 7.527354e-01      98.33389
# Dim.9  1.362272e-01 5.676134e-01      98.90150
# Dim.10 1.176732e-01 4.903050e-01      99.39180
# Dim.11 4.138572e-02 1.724405e-01      99.56424
# Dim.12 3.312271e-02 1.380113e-01      99.70226
# Dim.13 2.788597e-02 1.161916e-01      99.81845
# Dim.14 1.529647e-02 6.373531e-02      99.88218
# Dim.15 8.660709e-03 3.608629e-02      99.91827
# Dim.16 6.686581e-03 2.786075e-02      99.94613
# Dim.17 4.881952e-03 2.034147e-02      99.96647
# Dim.18 3.213200e-03 1.338833e-02      99.97986
# Dim.19 2.240620e-03 9.335916e-03      99.98920
# ...

# %% [markdown]
# ### PCA ciclo 22

# %%
data_22 <- data[8340:11903,]

# %%
# Compute principal component analysis
res.pca_22 <- prcomp(data_22, scale = TRUE)
# Percentage of information retained by each dimensions
fviz_eig(res.pca_22)
# Out:
# plot without title

# %%
fviz_pca_var(res.pca_22,
             col.var = "contrib", # Color by contributions to the PC
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"),
             repel = TRUE     # Avoid text overlapping
             )
# Out:
# plot without title

# %%
# Eigenvalues
eig.val <- get_eigenvalue(res.pca_22)
eig.val
  
# Results for Variables
res.var <- get_pca_var(res.pca_22)
res.var$coord          # Coordinates
res.var$contrib        # Contributions to the PCs
res.var$cos2           # Quality of representation 
# Results for individuals
res.ind <- get_pca_ind(res.pca_22)
res.ind$coord          # Coordinates
res.ind$contrib        # Contributions to the PCs
res.ind$cos2           # Quality of representation
# Out:
#        eigenvalue   variance.percent cumulative.variance.percent
# Dim.1  1.374679e+01 5.727830e+01      57.27830
# Dim.2  4.428249e+00 1.845104e+01      75.72933
# Dim.3  2.446599e+00 1.019416e+01      85.92350
# Dim.4  1.313236e+00 5.471815e+00      91.39531
# Dim.5  1.043935e+00 4.349729e+00      95.74504
# Dim.6  4.585133e-01 1.910472e+00      97.65551
# Dim.7  2.700240e-01 1.125100e+00      98.78061
# Dim.8  9.449595e-02 3.937331e-01      99.17435
# Dim.9  5.565577e-02 2.318990e-01      99.40625
# Dim.10 5.304081e-02 2.210034e-01      99.62725
# Dim.11 2.655839e-02 1.106600e-01      99.73791
# Dim.12 1.960671e-02 8.169462e-02      99.81960
# Dim.13 1.490972e-02 6.212385e-02      99.88173
# Dim.14 6.974350e-03 2.905979e-02      99.91079
# Dim.15 6.937827e-03 2.890761e-02      99.93970
# Dim.16 4.802564e-03 2.001068e-02      99.95971
# Dim.17 4.262478e-03 1.776032e-02      99.97747
# Dim.18 2.428739e-03 1.011974e-02      99.98759
# Dim.19 1.598331e-03 6.659714e-03      99.99425
# ...

# %% [markdown]
# ### PCA ciclo 23

# %%
data_23 <- data[11903:16408,]

# %%
# Compute principal component analysis
res.pca_23 <- prcomp(data_23, scale = TRUE)
# Percentage of information retained by each dimensions
fviz_eig(res.pca_23)
# Out:
# plot without title

# %%
fviz_pca_var(res.pca_23,
             col.var = "contrib", # Color by contributions to the PC
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"),
             repel = TRUE     # Avoid text overlapping
             )
# Out:
# plot without title

# %%
# Eigenvalues
eig.val <- get_eigenvalue(res.pca_23)
eig.val
  
# Results for Variables
res.var <- get_pca_var(res.pca_23)
res.var$coord          # Coordinates
res.var$contrib        # Contributions to the PCs
res.var$cos2           # Quality of representation 
# Results for individuals
res.ind <- get_pca_ind(res.pca_23)
res.ind$coord          # Coordinates
res.ind$contrib        # Contributions to the PCs
res.ind$cos2           # Quality of representation
# Out:
#        eigenvalue   variance.percent cumulative.variance.percent
# Dim.1  1.268681e+01 5.286171e+01      52.86171
# Dim.2  5.468326e+00 2.278469e+01      75.64640
# Dim.3  2.453824e+00 1.022427e+01      85.87067
# Dim.4  1.720263e+00 7.167762e+00      93.03843
# Dim.5  6.066822e-01 2.527843e+00      95.56627
# Dim.6  4.037386e-01 1.682244e+00      97.24852
# Dim.7  2.104788e-01 8.769952e-01      98.12551
# Dim.8  1.623054e-01 6.762727e-01      98.80179
# Dim.9  1.180381e-01 4.918254e-01      99.29361
# Dim.10 5.355625e-02 2.231510e-01      99.51676
# Dim.11 4.674272e-02 1.947614e-01      99.71152
# Dim.12 2.921579e-02 1.217324e-01      99.83326
# Dim.13 9.603479e-03 4.001450e-02      99.87327
# Dim.14 8.495531e-03 3.539805e-02      99.90867
# Dim.15 6.302761e-03 2.626150e-02      99.93493
# Dim.16 5.128160e-03 2.136733e-02      99.95630
# Dim.17 3.277798e-03 1.365749e-02      99.96996
# Dim.18 2.557229e-03 1.065512e-02      99.98061
# Dim.19 2.169145e-03 9.038106e-03      99.98965
# ...

# %% [markdown]
# ### PCA ciclo 24

# %%
install.packages("dplyr") # Instalar de manipulación de dataframes "dplyr"
# Out:
# also installing the dependency 'rlang'
# package 'rlang' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'rlang'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problema al copiar C:\Users\Miguel\.conda\envs\rstudio\lib\R\library\00LOCK\rlang\libs\x64\rlang.dll  a C:\Users\Miguel\.conda\envs\rstudio\lib\R\library\rlang\libs\x64\rlang.dll: Permission denied"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problema al copiar C:\Users\Miguel\.conda\envs\rstudio\lib\R\library\00LOCK\rlang\libs\x64\rlang.dll.c~.conda_trash  a C:\Users\Miguel\.conda\envs\rstudio\lib\R\library\rlang\libs\x64\rlang.dll.c~.conda_trash: Permission denied"Warning message:
# "restored 'rlang'"
# package 'dplyr' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'dplyr'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# ...

# %%
data_24 <- data[16408:20089,1:13]

# %%
# Compute principal component analysis
res.pca_24 <- prcomp(data_24, scale = TRUE)
# Percentage of information retained by each dimensions
fviz_eig(res.pca_24)
# Out:
# plot without title

# %%
fviz_pca_var(res.pca_24,
             col.var = "contrib", # Color by contributions to the PC
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"),
             repel = TRUE     # Avoid text overlapping
             )
# Out:
# plot without title

# %%
# Eigenvalues
eig.val <- get_eigenvalue(res.pca_24)
eig.val
  
# Results for Variables
res.var <- get_pca_var(res.pca_24)
res.var$coord          # Coordinates
res.var$contrib        # Contributions to the PCs
res.var$cos2           # Quality of representation 
# Results for individuals
res.ind <- get_pca_ind(res.pca_24)
res.ind$coord          # Coordinates
res.ind$contrib        # Contributions to the PCs
res.ind$cos2           # Quality of representation
# Out:
#        eigenvalue  variance.percent cumulative.variance.percent
# Dim.1  8.156514695 62.74242073       62.74242
# Dim.2  2.732006938 21.01543799       83.75786
# Dim.3  0.861032808  6.62332930       90.38119
# Dim.4  0.776837173  5.97567056       96.35686
# Dim.5  0.202663076  1.55894674       97.91581
# Dim.6  0.093526767  0.71943667       98.63524
# Dim.7  0.093252028  0.71732329       99.35257
# Dim.8  0.044027366  0.33867204       99.69124
# Dim.9  0.026324093  0.20249302       99.89373
# Dim.10 0.005121334  0.03939488       99.93313
# Dim.11 0.004175776  0.03212135       99.96525
# Dim.12 0.002879481  0.02214986       99.98740
# Dim.13 0.001638465  0.01260357      100.00000
#              Dim.1      Dim.2       Dim.3       Dim.4        Dim.5
# X             0.8176248  0.34970099 -0.29940262 -0.153783088  0.261062700
# B_mag         0.9272579 -0.26953354  0.08424073 -0.191758236 -0.077482171
# Proton_Temp   0.8779268  0.26507920  0.34892649  0.140480125  0.094351204
# ...
